# %%
# trained the model on CoCO dataset - it tooks me around 3h only for 20 epochs :( 
from ultralytics import YOLO


model = YOLO("yolo11l.pt")  


model.train(data=r"C:\Users\HP\Desktop\Machine learning\custom__dataset\data.yaml", epochs=20, imgsz=84, batch=8)

# %%
#But wait was worth as it was detecting my face perfectly and for unknow person my model was not even detecting them :)
import cv2
from ultralytics import YOLO


model = YOLO(r"C:\Users\HP\Desktop\Machine learning\runs\detect\train11\weights\best.pt") 


cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    
    results = model(frame)

    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0]) 
            conf = box.conf[0]  
            cls = int(box.cls[0])  
            
            if cls == 0:  
                label = f"Vedant ({conf:.2f})"
                color = (0, 255, 0) 
                
            else:  
                label = "Unknown"
                color = (0, 0, 255)  

            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    cv2.imshow("Face Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 96x96 2 Vedants, 110.5ms
# Speed: 0.0ms preprocess, 110.5ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 1 Vedant, 54.2ms
# Speed: 1.0ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 1 Vedant, 55.9ms
# Speed: 1.0ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 1 Vedant, 57.6ms
# Speed: 1.0ms preprocess, 57.6ms inference, 0.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 1 Vedant, 51.2ms
# Speed: 0.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 1 Vedant, 53.8ms
# Speed: 1.1ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 1 Vedant, 55.8ms
# Speed: 1.0ms preprocess, 55.8ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 1 Vedant, 46.1ms
# ...
