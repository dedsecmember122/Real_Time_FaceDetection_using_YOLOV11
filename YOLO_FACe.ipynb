# %%
from ultralytics import YOLO

# Load YOLOv11 model
model = YOLO("yolo11l.pt")  # This should match the YOLOv11 config

# Train model on your dataset
model.train(data=r"C:\Users\HP\Desktop\Machine learning\custom__dataset\data.yaml", epochs=20, imgsz=84, batch=8)  # Use 'cuda' if available
# Out:
# New https://pypi.org/project/ultralytics/8.3.72 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.70  Python-3.11.7 torch-2.5.1+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# ...

# %%
import cv2
from ultralytics import YOLO

# Load the trained YOLO model
model = YOLO(r"C:\Users\HP\Desktop\Machine learning\runs\detect\train11\weights\best.pt")  # Adjust path if needed

# Open webcam
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Detect faces using YOLO
    results = model(frame)

    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
            conf = box.conf[0]  # Confidence score
            cls = int(box.cls[0])  # Class index
            
            if cls == 0:  # "Vedant" class
                label = f"Vedant ({conf:.2f})"
                color = (0, 255, 0)  # Green for Vedant
            else:  # Any other face (not labeled)
                label = "Unknown"
                color = (0, 0, 255)  # Red for unknown faces

            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    cv2.imshow("Face Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 96x96 (no detections), 102.5ms
# Speed: 4.0ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 (no detections), 97.4ms
# Speed: 1.5ms preprocess, 97.4ms inference, 0.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 (no detections), 100.4ms
# Speed: 1.0ms preprocess, 100.4ms inference, 1.5ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 1 Vedant, 102.6ms
# Speed: 1.0ms preprocess, 102.6ms inference, 2.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 1 Vedant, 101.4ms
# Speed: 1.0ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 2 Vedants, 105.1ms
# Speed: 1.5ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 1 Vedant, 104.8ms
# Speed: 1.0ms preprocess, 104.8ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 96)
#
# 0: 96x96 2 Vedants, 95.9ms
# ...
